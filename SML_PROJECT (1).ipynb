# %%
import pandas as pd
data=pd.read_csv('/content/Advertising.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
x=data[['TV','Radio','Newspaper']]
y=data[['Sales']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(X_train)
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model=LinearRegression()
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_linear=linear_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(y_test,y_pred_linear)
mae
# Out:
# 1.4607567168117603

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred_linear)
mse
# Out:
# 3.1740973539761033

# %%
import numpy as np

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
mse_linear = mean_squared_error(y_test, y_pred_linear)
rmse = np.sqrt(mse_linear)
rmse
# Out:
# 1.78159966153345

# %%
from sklearn.svm import SVR

# %%
svr_model = SVR(kernel='rbf')
svr_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred_svr = svr_model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred_svr)
mae
# Out:
# 1.514357586594181

# %%
mse = mean_squared_error(y_test, y_pred_svr)
mse
# Out:
# 4.00604540443217

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 2.0015107804936174

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
Lasso_model=Lasso(alpha=1.0)
Lasso_model.fit(X_train,y_train)
# Out:
# Lasso()

# %%
y_pred_lasso=Lasso_model.predict(X_test)

# %%
mae=mean_absolute_error(y_test,y_pred_lasso)
mae
# Out:
# 1.4522022785934574

# %%
mse=mean_squared_error(y_test,y_pred_lasso)
mse
# Out:
# 3.143691505367937

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 1.7730458272046825

# %%
ridge_model=Ridge(alpha=1.0)
ridge_model.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_pred_ridge=ridge_model.predict(X_test)

# %%
mae=mean_absolute_error(y_test,y_pred_ridge)
mae
# Out:
# 1.460765611286965

# %%
mse=mean_squared_error(y_test,y_pred_ridge)
mse
# Out:
# 3.174094812092734

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 1.7815989481622216

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
mae_linear = mean_absolute_error(y_test, y_pred_linear)
mse_linear = mean_squared_error(y_test, y_pred_linear)
rmse_linear = np.sqrt(mse_linear)
result1 = {
    'Linear Regression': {'MAE': mae_linear, 'MSE': mse_linear, 'RMSE': rmse_linear}
}
result1
# Out:
# {'Linear Regression': {'MAE': 1.4607567168117603,
#   'MSE': 3.1740973539761033,
#   'RMSE': 1.78159966153345}}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
mae_svr = mean_absolute_error(y_test, y_pred_svr)
mse_svr = mean_squared_error(y_test, y_pred_svr)
rmse_svr = np.sqrt(mse_svr)
result2 = {
    'SVR': {'MAE': mae_svr, 'MSE': mse_svr, 'RMSE': rmse_svr}
}
result2
# Out:
# {'SVR': {'MAE': 1.514357586594181,
#   'MSE': 4.00604540443217,
#   'RMSE': 2.0015107804936174}}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
mae_lasso = mean_absolute_error(y_test, y_pred_lasso)
mse_lasso = mean_squared_error(y_test, y_pred_lasso)
rmse_lasso = np.sqrt(mse_lasso)
result3 = {
    'Lasso Regression': {'MAE': mae_lasso, 'MSE': mse_lasso, 'RMSE': rmse_lasso},
}
result3
# Out:
# {'Lasso Regression': {'MAE': 1.4522022785934574,
#   'MSE': 3.143691505367937,
#   'RMSE': 1.7730458272046825}}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
mae_ridge = mean_absolute_error(y_test, y_pred_ridge)
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mse_ridge)
result4 = {
    'Ridge Regression': {'MAE': mae_ridge, 'MSE': mse_ridge, 'RMSE': rmse_ridge}
}
result4
# Out:
# {'Ridge Regression': {'MAE': 1.460765611286965,
#   'MSE': 3.174094812092734,
#   'RMSE': 1.7815989481622216}}
